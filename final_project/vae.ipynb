# %% [markdown]
# # **Problem 3: Variational Autoencoders**

# %% [markdown]
# ## **About**
#
# ### **Due**
#
# Monday 10/16/20, 11:59 PM CST
#
# ### **Goal**
#
# This homework focuses on creating variational autoencoders applied to the MNIST dataset.

# %% [markdown]
# ### Installing PyTorch and Dependencies
#
# The instructions for installing and setting up PyTorch can be found at https://pytorch.org/get-started/locally/. Make sure you follow the instructions for your machine.\
# Check that PyTorch installed correctly by running the following:

# %%
import torch
torch.rand(5, 3)
# Out:
# tensor([[0.1757, 0.8194, 0.0205],
#         [0.9630, 0.5479, 0.8196],
#         [0.8267, 0.7883, 0.4878],
#         [0.4191, 0.2921, 0.3562],
#         [0.3534, 0.3148, 0.1180]])

# %% [markdown]
# The output should look something like
#
# ```python
# tensor([[0.3380, 0.3845, 0.3217],
#         [0.8337, 0.9050, 0.2650],
#         [0.2979, 0.7141, 0.9069],
#         [0.1449, 0.1132, 0.1375],
#         [0.4675, 0.3947, 0.1426]])
# ```
#
# ### Let's get started with the assignment.

# %% [markdown]
# ## **Instructions**
#
# ### **Part 1 - Datasets and Dataloaders**
#
#
# **Create a directory named problem3_data with the following command.**

# %%
# !mkdir problem3_data
# Out:
# mkdir: cannot create directory ‘problem3_data’: File exists

# %% [markdown]
# **Now use `torch.datasets.MNIST` to load the Train and Test data into `problem3_data`.**
# * ** Use the directory you created above as the `root` directory for your datasets**
# * ** Populate the `transformations` variable with any transformations you would like to perform on your data.** (Hint: You will need to do at least one)
# * **Pass your `transformations` variable to `torch.datasets.MNIST`. This allows you to perform arbitrary transformations to your data at loading time.**

# %%
from torchvision import datasets, transforms

## YOUR CODE HERE ##
batch_size = 32
loc_data = 'problem3_data'
latent_dim = 10
transformations = transforms.ToTensor()
mnist_train =  datasets.MNIST(loc_data, train=True, download=True, transform = transformations)
mnist_test = datasets.MNIST(loc_data, train=False, download=True, transform = transformations)

# %% [markdown]
# **Any file in our dataset will now be read at runtime, and the specified transformations we need on it will be applied when we need it.**.
#
# We could iterate through these directly using a loop, but this is not idiomatic. PyTorch provides us with this abstraction in the form of `DataLoaders`. The module of interest is `torch.utils.data.DataLoader`.
#
# `DataLoader` allows us to do lots of useful things
# * Group our data into batches
# * Shuffle our data
# * Load the data in parallel using `multiprocessing` workers
#
# **Use `DataLoader` to create a loader for the training set and one for the testing set**
# * **Use a `batch_size` of 32 to start, you may change it if you wish.**
# * **Set the `shuffle` parameter to `True`.**
#
# **Check that the data was loaded successfully before proceeding to the next sections. **

# %%
from torch.utils.data import DataLoader

## YOUR CODE HERE ##
train_loader = DataLoader(mnist_train,batch_size=batch_size,drop_last = True,shuffle=True)
test_loader = DataLoader(mnist_test,batch_size=batch_size,drop_last = True,shuffle=True)

# %% [markdown]
# ## **Part 2 - Encoder and Decoders (0 points)**
#
# In this section we will be creating the encoder and decoder for our variational autoencoder (VAE).
#
# You can take a look at the following to understand how VAE's work.
#
# *   https://towardsdatascience.com/intuitively-understanding-variational-autoencoders-1bfe67eb5daf
# *  http://kvfrans.com/variational-autoencoders-explained/
# *  https://jmetzen.github.io/2015-11-27/vae.html
#
# VAEs work around a latent space who's dimension can be chosen by us. We will leave this as a parameter for the Encoder and Decoder classes that you will have to populate.
#
# Feel free to use any network architecture that you wish. Try simpler network structures like a few linear layers before trying anything more complicated.
#
# ### For the Encoder:
#
# *   **Finish the __init__() function.**
# *  **Finish the forward() function.**
# *  **Assume that input to forward, x, is of shape (batch_size, 28,28)**
# *  **forward() should return two tensors of size latent_dim like a standard encoder of a VAE**
# * **One of the tensors should correspond to the mean of the encoding and the other tensor should correspond to the variance. In practice, it is easier to model the output as the log of the variance (logvar) and we will too**
#
# ### For the Decoder:
#
# *   **Finish the __init__() function.**
# *  **Finish the forward() function.**
# *  **Assume that input to forward, x, is of shape (batch_size, latent_dim)**
# *  **forward() should return a tensor of shape (batch_size, 28,28)**
# * **Make sure that the output lies in the same range as the input to the encoder (Hint: Sigmoid?)**

# %%
test_loader

# %%
from torch import nn
class Encoder(nn.Module):
  def __init__(self, latent_dim):
    super(Encoder, self).__init__()
    self.latent_dim = latent_dim
    self._encoder = nn.Sequential(nn.Linear(in_features = 28*28, out_features = 512),nn.ReLU(),nn.Linear(in_features = 512, out_features = 2*latent_dim))
  
  def forward(self, x):
    x = x.reshape((-1,28*28))    
    x = torch.reshape(self._encoder.forward(x), (-1, 2, self.latent_dim))
    mu, logvar = x[:,0,:], x[:,1,:]
    return mu, logvar, sample(mu, logvar) 

class Decoder(nn.Module):
  def __init__(self, latent_dim=10):
    super(Decoder, self).__init__()
    self.latent_dim = latent_dim
    self._decoder = nn.Sequential(nn.Linear(in_features = latent_dim, out_features = 512),nn.ReLU(),nn.Linear(in_features = 512, out_features = 28*28),nn.Sigmoid())
    
  def forward(self,x):
    return self._decoder.forward(x).reshape((-1,28,28))
# Out:
# 32768it [00:04, 6983.75it/s]
# 1654784it [00:04, 369439.26it/s]
# 8192it [00:03, 2272.10it/s]
# 9920512it [00:09, 1074155.91it/s]

# %% [markdown]
# ## **Part 3: Training and loss functions** (0 points)
#
# Recall that the encoder outputs the mean (mu) and the log of the variance (logvar). This implies that the latent vector of the input image follows a gaussian distribution with mean (mu) and standard deviation (e^[0.5\*logvar]). To decode this information, the decoder needs a sample from this distribution.
#
# **Complete the sample function to generate these samples **

# %%
def sample(mu, logvar):
  z = torch.randn_like(mu)
  return mu + torch.mul(torch.exp(0.5*logvar), z)

# %% [markdown]
# We also need to create the loss function. Assume that x are your input images and x_hat are your reconstructions of these input images, complete the following loss for a VAE. (Hint: You will need to use mu and logvar as well)

# %%
def vae_loss(x, x_hat, mu, logvar):
  mse = (x_hat - x).pow(2).sum()/(x.shape[0]*1.0)
  KL_loss = 0.5*torch.sum(-1 + torch.pow(mu,2) - logvar + torch.exp(logvar))/(x.shape[0]*1.0)
  return torch.add(mse, KL_loss)

# %% [markdown]
# In the following we will instantiate an Encoder and Decoder with a latent dimension of 32.
#
# We also define a single optimizer that optimizes the parameters of both the Encoder and the Decoder together. Feel free to use any optimizer of your choice.

# %%
from torch import optim

encoder = Encoder(latent_dim)
decoder = Decoder(latent_dim)
params = list(encoder.parameters())+list(decoder.parameters())
optimizer = optim.Adam(params, lr=1e-3)

# %% [markdown]
# Complete the train function that takes input encoder, decoder, train_loader, optimizer, and number of epochs you wish to train your model for.
#
# Training will involve:
#
# 1.   **One epoch is defined as a full pass of your dataset through your model. We choose the number of epochs we wish to train our model for.**
# 2.   **For each batch, use the encoder to generate the mu and logvar.**
# 3. **Sample a latent vector for each image in the batch and feed this to the decoder to generate the decoded images.**
# 4. **Calculate the loss function for this batch.**
# 5. **Now calculate the gradients for each parameter you are optimizing over. (Hint: Your loss function object can do this for you)**
# 6. **Update your model parameters (Hint: The optimizer comes in here)**
# 7. ** Set the gradients in your model to zero for the next batch.**

# %%
def train(encoder, decoder, train_loader, optimizer, num_epochs = 10):  
  encoder.train()
  decoder.train()
  for i in range(num_epochs):
    print("Epoch {}".format(i))
    for j, (x, y) in enumerate(train_loader):
        x = x.reshape((-1,28,28))
        _mu, _logvar, _z = encoder.forward(x)
        x_hat = decoder.forward(_z)
        optimizer.zero_grad()
        loss = vae_loss(x, x_hat, _mu, _logvar)
        loss.backward()
        optimizer.step()
        if j % 100 == 0:
            print(loss)            
  return loss

# %% [markdown]
# Finally call train with the relevant parameters.
#
# Note : This function may take a while to complete if you're training for many epochs on a cpu. This is where it comes in handy to be running on Google Colab, or just have a GPU on hand.

# %%
train(encoder, decoder, train_loader, optimizer, num_epochs = 100)
# Out:
# Epoch 0
# tensor(185.2799, grad_fn=<AddBackward0>)
# tensor(54.7616, grad_fn=<AddBackward0>)
# tensor(42.2387, grad_fn=<AddBackward0>)
# tensor(38.3703, grad_fn=<AddBackward0>)
# tensor(38.9633, grad_fn=<AddBackward0>)
# tensor(35.7212, grad_fn=<AddBackward0>)
# tensor(39.7583, grad_fn=<AddBackward0>)
# tensor(37.2214, grad_fn=<AddBackward0>)
# tensor(35.2419, grad_fn=<AddBackward0>)
# tensor(35.1537, grad_fn=<AddBackward0>)
# tensor(34.4609, grad_fn=<AddBackward0>)
# tensor(35.8811, grad_fn=<AddBackward0>)
# tensor(34.8106, grad_fn=<AddBackward0>)
# tensor(34.9109, grad_fn=<AddBackward0>)
# tensor(34.8184, grad_fn=<AddBackward0>)
# tensor(37.0253, grad_fn=<AddBackward0>)
# tensor(33.1781, grad_fn=<AddBackward0>)
# tensor(34.4690, grad_fn=<AddBackward0>)
# tensor(33.1365, grad_fn=<AddBackward0>)
# Epoch 1
# tensor(32.0516, grad_fn=<AddBackward0>)
# tensor(34.2073, grad_fn=<AddBackward0>)
# tensor(31.2793, grad_fn=<AddBackward0>)
# tensor(30.4061, grad_fn=<AddBackward0>)
# tensor(33.3843, grad_fn=<AddBackward0>)
# tensor(31.2590, grad_fn=<AddBackward0>)
# tensor(35.4462, grad_fn=<AddBackward0>)
# tensor(31.2824, grad_fn=<AddBackward0>)
# tensor(32.8885, grad_fn=<AddBackward0>)
# tensor(31.9809, grad_fn=<AddBackward0>)
# tensor(29.1508, grad_fn=<AddBackward0>)
# tensor(32.4451, grad_fn=<AddBackward0>)
# tensor(33.7695, grad_fn=<AddBackward0>)
# tensor(30.2038, grad_fn=<AddBackward0>)
# tensor(31.8078, grad_fn=<AddBackward0>)
# tensor(32.5789, grad_fn=<AddBackward0>)
# tensor(29.3339, grad_fn=<AddBackward0>)
# tensor(30.5323, grad_fn=<AddBackward0>)
# tensor(27.2780, grad_fn=<AddBackward0>)
# tensor(31.1893, grad_fn=<AddBackward0>)
# tensor(30.0737, grad_fn=<AddBackward0>)
# tensor(29.9752, grad_fn=<AddBackward0>)
# tensor(33.2231, grad_fn=<AddBackward0>)
# tensor(26.3726, grad_fn=<AddBackward0>)
# tensor(28.6108, grad_fn=<AddBackward0>)
# tensor(31.0031, grad_fn=<AddBackward0>)
# tensor(30.8010, grad_fn=<AddBackward0>)
# tensor(30.0185, grad_fn=<AddBackward0>)
# tensor(28.5939, grad_fn=<AddBackward0>)
# tensor(28.3327, grad_fn=<AddBackward0>)
# tensor(28.7420, grad_fn=<AddBackward0>)
# tensor(28.9265, grad_fn=<AddBackward0>)
# tensor(30.2415, grad_fn=<AddBackward0>)
# tensor(28.4709, grad_fn=<AddBackward0>)
# tensor(33.8161, grad_fn=<AddBackward0>)
# tensor(30.8960, grad_fn=<AddBackward0>)
# Epoch 6
# tensor(29.9173, grad_fn=<AddBackward0>)
# tensor(30.5251, grad_fn=<AddBackward0>)
# tensor(29.5269, grad_fn=<AddBackward0>)
# tensor(29.8296, grad_fn=<AddBackward0>)
# tensor(29.1443, grad_fn=<AddBackward0>)
# tensor(26.5686, grad_fn=<AddBackward0>)
# tensor(29.5123, grad_fn=<AddBackward0>)
# tensor(31.7140, grad_fn=<AddBackward0>)
# tensor(29.6375, grad_fn=<AddBackward0>)
# tensor(30.2608, grad_fn=<AddBackward0>)
# tensor(30.1867, grad_fn=<AddBackward0>)
# tensor(28.8423, grad_fn=<AddBackward0>)
# tensor(27.8445, grad_fn=<AddBackward0>)
# tensor(30.6534, grad_fn=<AddBackward0>)
# tensor(30.5015, grad_fn=<AddBackward0>)
# tensor(29.8289, grad_fn=<AddBackward0>)
# tensor(33.1437, grad_fn=<AddBackward0>)
# tensor(31.4628, grad_fn=<AddBackward0>)
# tensor(29.5438, grad_fn=<AddBackward0>)
# Epoch 7
# tensor(30.4237, grad_fn=<AddBackward0>)
# tensor(30.5989, grad_fn=<AddBackward0>)
# tensor(30.9738, grad_fn=<AddBackward0>)
# tensor(30.3981, grad_fn=<AddBackward0>)
# tensor(29.7885, grad_fn=<AddBackward0>)
# tensor(30.9708, grad_fn=<AddBackward0>)
# tensor(29.4187, grad_fn=<AddBackward0>)
# tensor(29.0417, grad_fn=<AddBackward0>)
# tensor(29.6494, grad_fn=<AddBackward0>)
# tensor(29.3481, grad_fn=<AddBackward0>)
# tensor(28.0426, grad_fn=<AddBackward0>)
# tensor(27.5452, grad_fn=<AddBackward0>)
# tensor(35.2170, grad_fn=<AddBackward0>)
# tensor(29.9490, grad_fn=<AddBackward0>)
# tensor(27.8115, grad_fn=<AddBackward0>)
# tensor(30.6328, grad_fn=<AddBackward0>)
# tensor(29.1962, grad_fn=<AddBackward0>)
# tensor(29.3499, grad_fn=<AddBackward0>)
# tensor(28.4806, grad_fn=<AddBackward0>)
# Epoch 8
# tensor(29.6826, grad_fn=<AddBackward0>)
# tensor(31.0554, grad_fn=<AddBackward0>)
# tensor(30.5591, grad_fn=<AddBackward0>)
# tensor(30.9655, grad_fn=<AddBackward0>)
# tensor(26.9784, grad_fn=<AddBackward0>)
# tensor(32.1121, grad_fn=<AddBackward0>)
# tensor(27.6597, grad_fn=<AddBackward0>)
# tensor(29.2581, grad_fn=<AddBackward0>)
# tensor(26.0456, grad_fn=<AddBackward0>)
# tensor(28.6243, grad_fn=<AddBackward0>)
# tensor(29.5788, grad_fn=<AddBackward0>)
# Epoch 18
# tensor(29.4948, grad_fn=<AddBackward0>)
# tensor(30.7715, grad_fn=<AddBackward0>)
# tensor(27.3065, grad_fn=<AddBackward0>)
# tensor(27.6809, grad_fn=<AddBackward0>)
# tensor(26.1294, grad_fn=<AddBackward0>)
# tensor(30.3751, grad_fn=<AddBackward0>)
# tensor(30.6370, grad_fn=<AddBackward0>)
# tensor(30.2549, grad_fn=<AddBackward0>)
# tensor(28.3012, grad_fn=<AddBackward0>)
# tensor(28.7624, grad_fn=<AddBackward0>)
# tensor(28.1515, grad_fn=<AddBackward0>)
# tensor(29.9909, grad_fn=<AddBackward0>)
# tensor(30.2702, grad_fn=<AddBackward0>)
# tensor(29.8745, grad_fn=<AddBackward0>)
# tensor(30.9747, grad_fn=<AddBackward0>)
# tensor(27.4599, grad_fn=<AddBackward0>)
# tensor(30.5447, grad_fn=<AddBackward0>)
# tensor(30.1779, grad_fn=<AddBackward0>)
# tensor(27.0242, grad_fn=<AddBackward0>)
# Epoch 19
# tensor(28.5346, grad_fn=<AddBackward0>)
# tensor(28.5120, grad_fn=<AddBackward0>)
# tensor(29.7368, grad_fn=<AddBackward0>)
# tensor(29.4975, grad_fn=<AddBackward0>)
# tensor(26.4533, grad_fn=<AddBackward0>)
# tensor(29.6003, grad_fn=<AddBackward0>)
# tensor(29.6839, grad_fn=<AddBackward0>)
# tensor(27.5641, grad_fn=<AddBackward0>)
# tensor(27.6675, grad_fn=<AddBackward0>)
# tensor(27.0225, grad_fn=<AddBackward0>)
# tensor(29.7800, grad_fn=<AddBackward0>)
# tensor(30.6003, grad_fn=<AddBackward0>)
# tensor(31.4404, grad_fn=<AddBackward0>)
# tensor(29.8917, grad_fn=<AddBackward0>)
# tensor(27.5529, grad_fn=<AddBackward0>)
# tensor(29.6578, grad_fn=<AddBackward0>)
# tensor(27.3672, grad_fn=<AddBackward0>)
# tensor(27.6471, grad_fn=<AddBackward0>)
# tensor(28.2033, grad_fn=<AddBackward0>)
# Epoch 20
# tensor(27.7202, grad_fn=<AddBackward0>)
# tensor(28.4499, grad_fn=<AddBackward0>)
# tensor(26.8128, grad_fn=<AddBackward0>)
# tensor(28.2459, grad_fn=<AddBackward0>)
# tensor(25.5674, grad_fn=<AddBackward0>)
# tensor(27.1280, grad_fn=<AddBackward0>)
# tensor(27.8389, grad_fn=<AddBackward0>)
# tensor(29.4052, grad_fn=<AddBackward0>)
# tensor(29.8981, grad_fn=<AddBackward0>)
# tensor(30.9450, grad_fn=<AddBackward0>)
# tensor(27.4350, grad_fn=<AddBackward0>)
# tensor(29.1783, grad_fn=<AddBackward0>)
# tensor(30.2406, grad_fn=<AddBackward0>)
# tensor(29.8568, grad_fn=<AddBackward0>)
# tensor(28.0891, grad_fn=<AddBackward0>)
# tensor(26.9090, grad_fn=<AddBackward0>)
# tensor(28.5437, grad_fn=<AddBackward0>)
# tensor(29.0634, grad_fn=<AddBackward0>)
# tensor(29.2002, grad_fn=<AddBackward0>)
# Epoch 21
# tensor(27.8654, grad_fn=<AddBackward0>)
# tensor(29.8513, grad_fn=<AddBackward0>)
# tensor(30.4906, grad_fn=<AddBackward0>)
# tensor(25.3793, grad_fn=<AddBackward0>)
# tensor(29.1966, grad_fn=<AddBackward0>)
# tensor(31.5960, grad_fn=<AddBackward0>)
# tensor(27.3811, grad_fn=<AddBackward0>)
# tensor(26.1918, grad_fn=<AddBackward0>)
# tensor(29.8684, grad_fn=<AddBackward0>)
# tensor(29.3885, grad_fn=<AddBackward0>)
# tensor(30.9608, grad_fn=<AddBackward0>)
# tensor(27.8346, grad_fn=<AddBackward0>)
# tensor(31.3906, grad_fn=<AddBackward0>)
# tensor(30.2811, grad_fn=<AddBackward0>)
# tensor(25.8982, grad_fn=<AddBackward0>)
# tensor(27.7387, grad_fn=<AddBackward0>)
# tensor(29.0973, grad_fn=<AddBackward0>)
# tensor(27.2871, grad_fn=<AddBackward0>)
# tensor(29.7137, grad_fn=<AddBackward0>)
# Epoch 22
# tensor(29.5408, grad_fn=<AddBackward0>)
# tensor(29.1596, grad_fn=<AddBackward0>)
# tensor(28.4333, grad_fn=<AddBackward0>)
# tensor(29.3983, grad_fn=<AddBackward0>)
# tensor(27.9237, grad_fn=<AddBackward0>)
# tensor(30.9130, grad_fn=<AddBackward0>)
# tensor(29.0573, grad_fn=<AddBackward0>)
# tensor(28.7942, grad_fn=<AddBackward0>)
# tensor(33.0292, grad_fn=<AddBackward0>)
# tensor(30.9214, grad_fn=<AddBackward0>)
# tensor(26.8395, grad_fn=<AddBackward0>)
# tensor(28.0945, grad_fn=<AddBackward0>)
# tensor(27.9328, grad_fn=<AddBackward0>)
# tensor(28.0236, grad_fn=<AddBackward0>)
# tensor(29.8799, grad_fn=<AddBackward0>)
# tensor(27.7939, grad_fn=<AddBackward0>)
# tensor(31.0614, grad_fn=<AddBackward0>)
# tensor(26.4667, grad_fn=<AddBackward0>)
# tensor(28.6408, grad_fn=<AddBackward0>)
# Epoch 23
# tensor(29.0645, grad_fn=<AddBackward0>)
# tensor(30.5823, grad_fn=<AddBackward0>)
# tensor(29.3016, grad_fn=<AddBackward0>)
# tensor(23.0806, grad_fn=<AddBackward0>)
# tensor(29.6285, grad_fn=<AddBackward0>)
# tensor(29.4317, grad_fn=<AddBackward0>)
# tensor(26.9566, grad_fn=<AddBackward0>)
# tensor(30.1754, grad_fn=<AddBackward0>)
# tensor(29.8323, grad_fn=<AddBackward0>)
# tensor(30.2424, grad_fn=<AddBackward0>)
# tensor(26.8359, grad_fn=<AddBackward0>)
# tensor(28.6384, grad_fn=<AddBackward0>)
# tensor(28.9515, grad_fn=<AddBackward0>)
# tensor(31.7104, grad_fn=<AddBackward0>)
# tensor(28.2500, grad_fn=<AddBackward0>)
# tensor(26.9124, grad_fn=<AddBackward0>)
# tensor(27.1053, grad_fn=<AddBackward0>)
# tensor(27.4346, grad_fn=<AddBackward0>)
# tensor(26.4196, grad_fn=<AddBackward0>)
# Epoch 24
# tensor(28.9123, grad_fn=<AddBackward0>)
# tensor(29.2247, grad_fn=<AddBackward0>)
# tensor(28.0981, grad_fn=<AddBackward0>)
# tensor(27.5409, grad_fn=<AddBackward0>)
# tensor(30.2121, grad_fn=<AddBackward0>)
# tensor(31.6079, grad_fn=<AddBackward0>)
# tensor(30.0865, grad_fn=<AddBackward0>)
# tensor(29.3452, grad_fn=<AddBackward0>)
# tensor(28.7031, grad_fn=<AddBackward0>)
# tensor(28.9234, grad_fn=<AddBackward0>)
# tensor(30.7780, grad_fn=<AddBackward0>)
# tensor(27.8298, grad_fn=<AddBackward0>)
# tensor(28.1266, grad_fn=<AddBackward0>)
# tensor(31.4199, grad_fn=<AddBackward0>)
# tensor(29.4099, grad_fn=<AddBackward0>)
# tensor(26.8571, grad_fn=<AddBackward0>)
# tensor(28.7081, grad_fn=<AddBackward0>)
# tensor(27.9642, grad_fn=<AddBackward0>)
# tensor(27.7246, grad_fn=<AddBackward0>)
# Epoch 25
# tensor(25.4364, grad_fn=<AddBackward0>)
# tensor(28.3211, grad_fn=<AddBackward0>)
# tensor(24.9746, grad_fn=<AddBackward0>)
# tensor(29.9206, grad_fn=<AddBackward0>)
# tensor(30.0883, grad_fn=<AddBackward0>)
# tensor(27.5275, grad_fn=<AddBackward0>)
# tensor(26.6930, grad_fn=<AddBackward0>)
# tensor(30.5613, grad_fn=<AddBackward0>)
# tensor(28.0820, grad_fn=<AddBackward0>)
# tensor(26.4590, grad_fn=<AddBackward0>)
# tensor(26.6665, grad_fn=<AddBackward0>)
# tensor(31.2018, grad_fn=<AddBackward0>)
# tensor(29.2332, grad_fn=<AddBackward0>)
# tensor(27.7816, grad_fn=<AddBackward0>)
# tensor(28.1236, grad_fn=<AddBackward0>)
# tensor(28.2467, grad_fn=<AddBackward0>)
# tensor(26.9165, grad_fn=<AddBackward0>)
# tensor(27.7467, grad_fn=<AddBackward0>)
# tensor(26.8486, grad_fn=<AddBackward0>)
# Epoch 26
# tensor(29.1824, grad_fn=<AddBackward0>)
# tensor(30.5348, grad_fn=<AddBackward0>)
# tensor(29.5454, grad_fn=<AddBackward0>)
# tensor(28.6141, grad_fn=<AddBackward0>)
# tensor(29.5878, grad_fn=<AddBackward0>)
# tensor(29.2849, grad_fn=<AddBackward0>)
# tensor(28.5498, grad_fn=<AddBackward0>)
# tensor(30.3223, grad_fn=<AddBackward0>)
# tensor(26.3197, grad_fn=<AddBackward0>)
# tensor(26.0142, grad_fn=<AddBackward0>)
# tensor(25.5064, grad_fn=<AddBackward0>)
# tensor(30.7750, grad_fn=<AddBackward0>)
# tensor(26.1682, grad_fn=<AddBackward0>)
# tensor(28.5014, grad_fn=<AddBackward0>)
# tensor(29.8271, grad_fn=<AddBackward0>)
# tensor(27.0900, grad_fn=<AddBackward0>)
# tensor(31.3450, grad_fn=<AddBackward0>)
# tensor(31.3028, grad_fn=<AddBackward0>)
# tensor(28.3071, grad_fn=<AddBackward0>)
# Epoch 27
# tensor(28.2685, grad_fn=<AddBackward0>)
# tensor(28.3065, grad_fn=<AddBackward0>)
# tensor(27.6791, grad_fn=<AddBackward0>)
# tensor(28.2757, grad_fn=<AddBackward0>)
# tensor(28.1194, grad_fn=<AddBackward0>)
# tensor(28.4661, grad_fn=<AddBackward0>)
# tensor(29.0768, grad_fn=<AddBackward0>)
# tensor(26.6854, grad_fn=<AddBackward0>)
# tensor(25.0979, grad_fn=<AddBackward0>)
# tensor(28.4145, grad_fn=<AddBackward0>)
# tensor(30.1561, grad_fn=<AddBackward0>)
# tensor(26.4351, grad_fn=<AddBackward0>)
# tensor(28.6920, grad_fn=<AddBackward0>)
# tensor(31.7497, grad_fn=<AddBackward0>)
# tensor(26.6242, grad_fn=<AddBackward0>)
# tensor(28.7002, grad_fn=<AddBackward0>)
# tensor(28.1653, grad_fn=<AddBackward0>)
# tensor(27.8931, grad_fn=<AddBackward0>)
# tensor(29.0193, grad_fn=<AddBackward0>)
# Epoch 28
# tensor(27.0056, grad_fn=<AddBackward0>)
# tensor(30.2761, grad_fn=<AddBackward0>)
# tensor(28.2975, grad_fn=<AddBackward0>)
# tensor(29.6951, grad_fn=<AddBackward0>)
# tensor(27.1092, grad_fn=<AddBackward0>)
# tensor(30.2858, grad_fn=<AddBackward0>)
# tensor(29.8061, grad_fn=<AddBackward0>)
# tensor(28.7086, grad_fn=<AddBackward0>)
# tensor(29.0533, grad_fn=<AddBackward0>)
# tensor(24.8283, grad_fn=<AddBackward0>)
# tensor(31.0564, grad_fn=<AddBackward0>)
# tensor(27.8825, grad_fn=<AddBackward0>)
# tensor(27.3436, grad_fn=<AddBackward0>)
# tensor(30.1455, grad_fn=<AddBackward0>)
# tensor(26.8114, grad_fn=<AddBackward0>)
# tensor(27.4552, grad_fn=<AddBackward0>)
# tensor(29.1730, grad_fn=<AddBackward0>)
# tensor(27.6789, grad_fn=<AddBackward0>)
# tensor(26.6298, grad_fn=<AddBackward0>)
# Epoch 29
# tensor(28.8461, grad_fn=<AddBackward0>)
# tensor(28.2907, grad_fn=<AddBackward0>)
# tensor(26.4359, grad_fn=<AddBackward0>)
# tensor(29.8782, grad_fn=<AddBackward0>)
# tensor(27.1078, grad_fn=<AddBackward0>)
# tensor(28.2674, grad_fn=<AddBackward0>)
# tensor(27.0582, grad_fn=<AddBackward0>)
# tensor(28.4643, grad_fn=<AddBackward0>)
# tensor(25.6774, grad_fn=<AddBackward0>)
# tensor(32.0069, grad_fn=<AddBackward0>)
# tensor(29.3382, grad_fn=<AddBackward0>)
# tensor(27.8088, grad_fn=<AddBackward0>)
# tensor(25.6273, grad_fn=<AddBackward0>)
# tensor(27.4107, grad_fn=<AddBackward0>)
# tensor(28.5190, grad_fn=<AddBackward0>)
# tensor(29.0114, grad_fn=<AddBackward0>)
# tensor(27.4925, grad_fn=<AddBackward0>)
# tensor(25.7626, grad_fn=<AddBackward0>)
# tensor(31.1040, grad_fn=<AddBackward0>)
# Epoch 30
# tensor(27.6463, grad_fn=<AddBackward0>)
# tensor(27.2796, grad_fn=<AddBackward0>)
# tensor(31.7605, grad_fn=<AddBackward0>)
# tensor(25.9940, grad_fn=<AddBackward0>)
# tensor(30.6606, grad_fn=<AddBackward0>)
# tensor(27.8124, grad_fn=<AddBackward0>)
# tensor(30.8709, grad_fn=<AddBackward0>)
# tensor(26.7671, grad_fn=<AddBackward0>)
# tensor(26.7455, grad_fn=<AddBackward0>)
# tensor(25.9052, grad_fn=<AddBackward0>)
# tensor(28.8029, grad_fn=<AddBackward0>)
# tensor(24.9403, grad_fn=<AddBackward0>)
# tensor(30.3523, grad_fn=<AddBackward0>)
# tensor(29.6864, grad_fn=<AddBackward0>)
# tensor(29.5097, grad_fn=<AddBackward0>)
# tensor(28.5974, grad_fn=<AddBackward0>)
# tensor(30.7614, grad_fn=<AddBackward0>)
# tensor(28.5544, grad_fn=<AddBackward0>)
# tensor(27.6611, grad_fn=<AddBackward0>)
# Epoch 31
# tensor(30.9832, grad_fn=<AddBackward0>)
# tensor(30.1382, grad_fn=<AddBackward0>)
# tensor(27.5855, grad_fn=<AddBackward0>)
# tensor(23.1496, grad_fn=<AddBackward0>)
# tensor(28.9805, grad_fn=<AddBackward0>)
# tensor(28.2922, grad_fn=<AddBackward0>)
# tensor(28.8801, grad_fn=<AddBackward0>)
# tensor(28.7475, grad_fn=<AddBackward0>)
# tensor(27.1609, grad_fn=<AddBackward0>)
# tensor(28.5005, grad_fn=<AddBackward0>)
# tensor(27.0186, grad_fn=<AddBackward0>)
# tensor(27.0573, grad_fn=<AddBackward0>)
# tensor(28.8851, grad_fn=<AddBackward0>)
# tensor(27.9392, grad_fn=<AddBackward0>)
# tensor(31.5956, grad_fn=<AddBackward0>)
# tensor(30.0581, grad_fn=<AddBackward0>)
# tensor(28.1487, grad_fn=<AddBackward0>)
# tensor(25.8343, grad_fn=<AddBackward0>)
# tensor(29.4195, grad_fn=<AddBackward0>)
# Epoch 32
# tensor(28.4264, grad_fn=<AddBackward0>)
# tensor(24.6327, grad_fn=<AddBackward0>)
# tensor(32.9232, grad_fn=<AddBackward0>)
# tensor(27.5586, grad_fn=<AddBackward0>)
# tensor(29.0747, grad_fn=<AddBackward0>)
# tensor(28.1713, grad_fn=<AddBackward0>)
# tensor(27.2421, grad_fn=<AddBackward0>)

# %% [markdown]
# ## **Part 4: Visualizing the VAE output** (50 points)
#
# We will look at how well the codes produced by the VAE can be interpolated. **For this section we will only use the MNIST test set. **
#
# To create an interpolation between two images A and B, we encode both these images and generate a sample code for each of them. We now consider 7 equally spaced points in between these two sample codes giving us a total of 9 points including the samples. We then decode these images to get interpolated images in between A and B.
#
# Complete the interpolation function below that takes a pair of images A and B and returns 9 images. (You are free to use any data structure you want to return these images)

# %%
import matplotlib.pyplot as plt
from torchvision import utils
# %matplotlib inline
import numpy as np

def create_interpolates(A, B, encoder, decoder):
  ## Assuming A and B are images of shape (28,28)
  _, _, zA = encoder(A.reshape((-1, 28*28)))  
  _, _, zB = encoder(B.reshape((-1, 28*28)))
  image_list = []
  nimages = 9
  dZ = zB - zA
  z_list = [zA + dZ*(i*1.0/(nimages-1)) for i in range(nimages)]
  image_list = []
  for z in z_list:
    image_list.append(decoder(z).reshape((28,28)).detach().numpy())
  return np.concatenate(tuple(image_list), axis = 1)

# %% [markdown]
# **For 10 pairs of MNIST test images of the same digit (1 pair for "0", 1 pair for "1", etc.), selected at random, compute the code for each image of the pair. Now compute 7 evenly spaced linear interpolates between these codes, and decode the result into images. Prepare a figure showing this interpolate. Lay out the figure so each interpolate is a row. On the left of the row is the first test image; then the interpolate closest to it; etc; to the last test image. You should have a 10 rows (1 row per digit) and 9 columns (7 interpolates + 2 selected test images) of images. (25 points)**

# %%
similar_pairs = {}
for _, (x, y) in enumerate(test_loader):
  for i in range(len(y)):
    if y[i].item() not in similar_pairs:
      similar_pairs[y[i].item()] = []
    if len(similar_pairs[y[i].item()])<2:
      similar_pairs[y[i].item()].append(x[i])
  
  done = True
  for i in range(10):
    if i not in similar_pairs or len(similar_pairs[i])<2:
      done = False
  
  if done:
    break

# similar_pairs[i] contains two images indexed at 0 and 1 that have images of the digit i

fig = plt.figure(figsize=(20,18))
for i in sorted(similar_pairs.keys()):
  images = create_interpolates(similar_pairs[i][0], similar_pairs[i][1], encoder, decoder) 
  plt.subplot(10,1,i +1)
  plt.tight_layout()
  plt.imshow(images, cmap='gray', interpolation='none')
  plt.xticks([])
  plt.yticks([])
  plt.subplots_adjust(wspace=0, hspace=0)

# %% [markdown]
# **For 10 pairs of MNIST test images, selected at random, compute the code for each image of the pair. Now compute 7 evenly spaced linear interpolates between these codes, and decode the result into images. Prepare a figure showing this interpolate. Lay out the figure so each interpolate is a row. On the left of the row is the first test image; then the interpolate closest to it; etc; to the last test image. You should have a 10 rows and 9 columns of images. (25 points)**

# %%
random_pairs = {}
for _, (x, y) in enumerate(test_loader):
  # Make sure the batch size is greater than 20
  for i in range(10):
    random_pairs[i] = []
    random_pairs[i].append(x[2*i])
    #print(y[2*i].item())
    random_pairs[i].append(x[2*i+1])
    #print(y[2*i+1].item())
  break

# random_pairs[i] contains two images indexed at 0 and 1 that are chosen at random

fig = plt.figure(figsize=(20,18))
for i in sorted(random_pairs.keys()):
  images = create_interpolates(random_pairs[i][0], random_pairs[i][1], encoder, decoder) 
  plt.subplot(10,1,i +1)
  plt.tight_layout()
  plt.imshow(images, cmap='gray', interpolation='none')
  plt.xticks([])
  plt.yticks([])
  plt.subplots_adjust(wspace=0, hspace=0)

# %%
from sklearn.manifold import TSNE


Imageslist = []
Tmageslabel = []
# get all the test images and labels in test set and use encode to compute the latent vector z
for i, data in enumerate(test_loader):
    inputs, labels = data
    for j in range(len(labels)):
        Imageslist.append(inputs[j])
        Tmageslabel.append(labels[j].item())

#convert the tensor into numpy
test_features = []
for i in range(len(Imageslist)):
     _, _, z = encoder(Imageslist[i])
     z = z.detach().numpy()
     z = np.squeeze(z)
     test_features.append(z)
    
test_features = np.array(test_features)
test_labels = np.array(Tmageslabel)

#reduce dimensionality to 2D, we consider a subset of data because TSNE
tsne_features = TSNE(n_components=2).fit_transform(test_features)

fig = plt.figure(figsize=(10, 6))

plt.scatter(tsne_features[:, 0], tsne_features[:, 1], c=test_labels[:tsne_features.shape[0]], marker='o',
            edgecolor='none', cmap=plt.cm.get_cmap('jet', 10), s = 10)
plt.grid(False)
plt.axis('off')
plt.colorbar()
